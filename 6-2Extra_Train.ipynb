# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#读入数据以及做必要的预处理
dpath_train='F:\\Study\\data\\lastmission\\Music Recommendation\\Data\\train.csv\\train.csv'
dpath_songs='F:\\Study\\data\\lastmission\\Music Recommendation\\Data\\songs.csv\\songs.csv'
dpath_songs_extra='F:\\Study\\data\\lastmission\\Music Recommendation\\Data\\song_extra_info.csv\\song_extra_info.csv'
dpath_mambers='F:\\Study\\data\\lastmission\\Music Recommendation\\Data\\members.csv\\members.csv'

# %%
#提取100w条作为训练
df=pd.read_csv(dpath_train, error_bad_lines=False, nrows = 1000000)
dfs=pd.read_csv(dpath_songs,error_bad_lines=False)
dfm=pd.read_csv(dpath_mambers, error_bad_lines=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 6 columns):
# msno                  1000000 non-null object
# song_id               1000000 non-null object
# source_system_tab     997061 non-null object
# source_screen_name    953766 non-null object
# source_type           997403 non-null object
# target                1000000 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 45.8+ MB

# %%
dfs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2296320 entries, 0 to 2296319
# Data columns (total 7 columns):
# song_id        object
# song_length    int64
# genre_ids      object
# artist_name    object
# composer       object
# lyricist       object
# language       float64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 122.6+ MB

# %%
df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 2  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 3  Xumu+NIjS6QYVxDS4/t3SawvJ7viT9hPKXmf0RtLNx8=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  bhp/MpSNoqoxOIB+/l8WPqu6jldth4DIpCm3ayXnJqM=        my library
# 2  JNWfrrC7zNN7BdMpsISKa4Mw+xVJYNnxXh3/Epw7QgY=        my library
# 3  2A87tzfnJTSWqD7gIZHisolhe4DMdzkbd6LzO1KHjNs=        my library
# 4  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
#
#     source_screen_name      source_type  target
# 0              Explore  online-playlist       1
# 1  Local playlist more   local-playlist       1
# 2  Local playlist more   local-playlist       1
# 3  Local playlist more   local-playlist       1
# ...

# %%
df = pd.merge(df,dfs,left_on='song_id',right_on='song_id')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 999984 entries, 0 to 999983
# Data columns (total 12 columns):
# msno                  999984 non-null object
# song_id               999984 non-null object
# source_system_tab     997045 non-null object
# source_screen_name    953750 non-null object
# source_type           997387 non-null object
# target                999984 non-null int64
# song_length           999984 non-null int64
# genre_ids             985364 non-null object
# artist_name           999984 non-null object
# composer              787614 non-null object
# lyricist              589551 non-null object
# language              999978 non-null float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 99.2+ MB

# %%
df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  e5Ezre9HPuPos+CXQXtmo32E/hHIZTMmo6jG3yRf6UA=
# 2  pouJqjNRmZOnRNzzMWWkamTKkIGHyvhl/jo4HgbncnM=
# 3  sSexP400TJOZRhx3JB+0s9cqrCnqrlV51B9njoKR1II=
# 4  hKdGiUKHVqKkXGHLrc+EzdSW6q0ERAJ2Cs7/L1N0Ae4=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=        my library
# 2  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
# 3  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
# 4  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=          discover
#
#      source_screen_name      source_type  target  song_length genre_ids  \
# 0               Explore  online-playlist       1       206471       359
# 1   Local playlist more   local-playlist       1       206471       359
# ...

# %%
df = pd.merge(df,dfm,left_on='msno',right_on='msno')

# %%
df.head()
# Out:
#                                            msno  \
# 0  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 1  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 2  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 3  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
# 4  FGtllVqz18RPiwJj/edr2gV78zirAiY/9SmYvia+kCg=
#
#                                         song_id source_system_tab  \
# 0  BBzumQNXUHKdEBOB7mAJuzok+IJA1c2Ryg/yzTF6tik=           explore
# 1  3qm6XTZ6MOCU11x8FIVbAGH5l5uMkT3/ZalWG1oo2Gc=           explore
# 2  3Hg5kugV1S0wzEVLAEfqjIV5UHzb7bCrdBRQlGygLvU=           explore
# 3  bPIvRTzfHxH5LgHrStll+tYwSQNVV8PySgA3M1PfTgc=           explore
# 4  GFWjz4apE8zMiXe6wc0qCjr+DbK9BFkwo/rr+FsNm+g=            search
#
#   source_screen_name          source_type  target  song_length genre_ids  \
# 0            Explore      online-playlist       1       206471       359
# 1            Explore      online-playlist       1       187802      1011
# ...

# %%
df.columns.values
# Out:
# array(['msno', 'song_id', 'source_system_tab', 'source_screen_name',
#        'source_type', 'target', 'song_length', 'genre_ids', 'artist_name',
#        'composer', 'lyricist', 'language', 'city', 'bd', 'gender',
#        'registered_via', 'registration_init_time', 'expiration_date'],
#       dtype=object)

# %%
df = df.drop(['msno', 'song_id'], axis=1)
df.columns.values
# Out:
# array(['source_system_tab', 'source_screen_name', 'source_type', 'target',
#        'song_length', 'genre_ids', 'artist_name', 'composer', 'lyricist',
#        'language', 'city', 'bd', 'gender', 'registered_via',
#        'registration_init_time', 'expiration_date'], dtype=object)

# %%
df.to_csv('6-2Extra_Train_First.csv',index=False,header=True)
